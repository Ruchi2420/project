# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
flipcart_url = "https://www.flipkart.com/search?q=" + "Tv"

# %%
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=Tv'

# %%
urlclient = urlopen(flipcart_url)

# %%
flipcart_page = urlclient.read()

# %%
flipcart_html = bs(flipcart_page,'html.parser') ##beautifies all the data of html

# %%
"https://www.flipkart.com"+"/sansui-109-cm-43-inch-ultra-hd-4k-led-smart-android-tv-dolby-audio-dts-mystique-black-2022-model/p/itm7b83d44bd264a?pid=TVSFWFSH7VHWPG4Y&lid=LSTTVSFWFSH7VHWPG4YF8MNR2&marketplace=FLIPKART&q=Tv&store=ckf%2Fczl&srno=s_1_1&otracker=search&fm=organic&iid=en_Y0chhrIzChhybWcRC3kJcsu2OnDwZwfVZFIrby756pf0hzgDp4bRLc61gXxXfkZ%2BGz0E7knyswJ5Ta6d1FI41g%3D%3D&ppt=sp&ppn=sp&ssid=fw2xwvkqsw0000001677408936467&qH=7428554abf279ee0"
# Out:
# 'https://www.flipkart.com/sansui-109-cm-43-inch-ultra-hd-4k-led-smart-android-tv-dolby-audio-dts-mystique-black-2022-model/p/itm7b83d44bd264a?pid=TVSFWFSH7VHWPG4Y&lid=LSTTVSFWFSH7VHWPG4YF8MNR2&marketplace=FLIPKART&q=Tv&store=ckf%2Fczl&srno=s_1_1&otracker=search&fm=organic&iid=en_Y0chhrIzChhybWcRC3kJcsu2OnDwZwfVZFIrby756pf0hzgDp4bRLc61gXxXfkZ%2BGz0E7knyswJ5Ta6d1FI41g%3D%3D&ppt=sp&ppn=sp&ssid=fw2xwvkqsw0000001677408936467&qH=7428554abf279ee0'

# %%
bigbox=flipcart_html.find_all("div",{"class":"_1AtVbE col-12-12"})

# %%
len(bigbox)
# Out:
# 30

# %%
del bigbox[0:1]

# %%
productlink="https://www.flipkart.com" + bigbox[0].div.div.div.a['href']

# %%
for i in bigbox:
    print("https://www.flipkart.com" + bigbox[0].div.div.div.a['href'])
# Out:
# https://www.flipkart.com/samsung-80-cm-32-inch-hd-ready-led-smart-tizen-tv-2022-model/p/itm3c07ddc2dd25d?pid=TVSGHY2UZA9YHWQN&lid=LSTTVSGHY2UZA9YHWQNNQENTU&marketplace=FLIPKART&q=Tv&store=ckf%2Fczl&spotlightTagId=BestsellerId_ckf%2Fczl&srno=s_1_3&otracker=search&fm=organic&iid=cbdcee0a-11dd-41b3-a36f-c429e8074312.TVSGHY2UZA9YHWQN.SEARCH&ppt=None&ppn=None&ssid=c2inws35k00000001677409069178&qH=7428554abf279ee0
# https://www.flipkart.com/samsung-80-cm-32-inch-hd-ready-led-smart-tizen-tv-2022-model/p/itm3c07ddc2dd25d?pid=TVSGHY2UZA9YHWQN&lid=LSTTVSGHY2UZA9YHWQNNQENTU&marketplace=FLIPKART&q=Tv&store=ckf%2Fczl&spotlightTagId=BestsellerId_ckf%2Fczl&srno=s_1_3&otracker=search&fm=organic&iid=cbdcee0a-11dd-41b3-a36f-c429e8074312.TVSGHY2UZA9YHWQN.SEARCH&ppt=None&ppn=None&ssid=c2inws35k00000001677409069178&qH=7428554abf279ee0
# ...

# %%
productlink
# Out:
# 'https://www.flipkart.com/thomson-126-cm-50-inch-qled-ultra-hd-4k-smart-google-tv-dolby-vision-atmos/p/itma89c8d0f53b5c?pid=TVSGHADTWZAWZXSF&lid=LSTTVSGHADTWZAWZXSFA4HE74&marketplace=FLIPKART&q=Tv&store=ckf%2Fczl&srno=s_1_2&otracker=search&fm=organic&iid=en_5YyiAhIySFyS6B5w6H4eNpym7nBgZpT6XsCEwtNIXoMsMOp83RIIpACgkrJGcyiSH359Kjw2lv%2FGhblUys6pRw%3D%3D&ppt=None&ppn=None&ssid=c2inws35k00000001677409069178&qH=7428554abf279ee0'

# %%
product_req=requests.get(productlink)

# %%
product_html = bs(product_req.text,'html')

# %%
product_html
# Out:
# <!DOCTYPE html>
# ...
